# %%
# !wget https://s3.amazonaws.com/hr-testcases/859/assets/training.json
# Out:
# --2019-07-02 15:42:21--  https://s3.amazonaws.com/hr-testcases/859/assets/training.json
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.111.77
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.111.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2321936 (2.2M) [application/octet-stream]
# Saving to: ‘training.json’
#
# training.json       100%[===================>]   2.21M  --.-KB/s    in 0.08s
#
# 2019-07-02 15:42:21 (26.6 MB/s) - ‘training.json’ saved [2321936/2321936]

# %%
import json    

data = []
with open('training.json') as f:
    for line in f:
        data.append(json.loads(line))

# %%
data
# Out:
# [20217,
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'New batteries C-S2 for Blackberry 7100/7130/8700/Curve/Pearl',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': '*******   Brand New Original SAMSUNG GALAXY NOTE 2 BATTERY ******',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'SAMSUNG GALAXY SIII T-999 MARBLE WHITE T-MOBILE SMARTPHONE BRAND NEW',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'Ipad mini 64gb 4g any sim unlock ',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'htc evo 4g lte for trade',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'Iphone T-mobile Unlock Phone New ',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'map',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'at&amp;t iphone 5 32gb black good condition no scratches at all $550',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': ' iphone 5 white from Tmobile with lifeproof case ',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'I-phone 4',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'I PHONE 4 ',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'LG Spectrum 2 Shell Holster Case',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'OtterBox Defender Case for iPhone 4S ',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'factory Unlocked iphone 5 16gb',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'Samsung Galaxy S3 16G ',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'iphone 5 white 16 gb at&amp;t Factory unlocked tmobile simple 16gb',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'Unlocked Blackberry Bold 9900',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'iPhone 5 tmobile 32gb black 10-10',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'ALL Samsung PHONES Unlock &amp; IMEI Fix Service ',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'ALL Samsung PHONES  Unlock &amp; IMEI Fix Service',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'i want to buy ipad 4,wifi,4g,mini,iphone 5/4/4s,,macbook pro,air,imac,,retina ap',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'sprint iphone for sale mint ',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'HTC Vivid',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'Galaxy s4 Grand Dous',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'IPHONE 5 unlocked Trade/for sale',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'iPhone 5 charger',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'SAMSUNG GALAXY S2 (sprint)',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'factory unlocked black iphone 4 32Gb at&amp;t  mint ',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'factory unlocked black iphone 4 8gb ',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'Unlocked black iPhone 4 8gb at&amp;t like new ',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'Black Sprint iPhone 4 8gb (bad esn)',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'Samsung Galaxy S3 Black Factory Unlocked',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': ' ((( the best part is I will come to you 20 minutes  repair iPhone )))',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'Like new jailbreak white iPhone 4 for sprint ',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'FS: iphone 4 16 gb (unlocked) ',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'iphone and galaxy screen repair ',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': ' Samsung Galaxay 3 rooted!!.verizon',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'LG Prada 3.0 - 8GB   Unlocked',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': '=&gt;&gt; IPHONE 5 &amp; GALAXY NOTE 2 ***LIKE NEW, UNLOCKED*** for SALE/ TRADE',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'New In Box Galaxy note 2',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'COLOMBIANOS POR FAVOR LEA (RECOMPENSA)',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'Fast Motorola Droid Razr Maxx - 16GB New and Original Factory Unlocked',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'Samsung Galaxy Note 2 -16GB- White (T-Mobile) Smartphone - MINT CONDITION****',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'Samsung Galaxy S4 i9505 HD unlocked white.New',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'iPhone 4 for sprint 8 gig',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'Verizon Galaxy Note 2 Metalic Gray Brand New In Box W/Cover 299.99',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'iPhone 5 - 16GB White - (Factory Unlocked) MINT CONDITION',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'white galaxy note 2 for s/t f.unlocked',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': ' iPhone5 we want AT&amp;T&amp; Verizon used or cracked - $350 (Queens Brooklyn',
#   'section': 'for-sale'},
#  {'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': '

#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': '_________ FREE CABLE TV and MOVIES! - - - - - - - ',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Polaroid Sun 660 Camera',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Sony Cybershot Camera,Dell compact Photo Printer(3x5x7)Perfect cond',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Set Shop Saw Horses custom made forfor photography excellent condition',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': '2 Brand New unused 30 ft. 6pin to 6pin Firewire Cable in box',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'ClearViewer Premium Viewfinder for Sony RX100 Camera',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Photogenic Lighting Kit for Sale or Trade',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'NEW Sony DVD Digital Camcorder Handycam w EXTRAS!',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Nikon D5100 DSLR',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'map',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Keystone Riviera K-45 8mm movie camera',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'map',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Two Altman 3.5" Ellipsoidals/Lekos',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Nikon D3100 with 18-55 &amp; 55-200 Lenses - Like New - Low Shutter Clicks',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Nikon D90 with 18-105mm - Low Shutter Clicks',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Printer -  Epson Stylus Pro 9600',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Nikon FM10 35mm film SLR camera and EXTRAS',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Nikon AF-S 55-200 mm VR lens',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Kodak 750 H Carousel Slide Projector',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'For Sale or Trade Nikon 55-200 VR lens',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Honeycomb grids for profoto magnum',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Lensbaby Composer Pro Sweet 35 Optic Muse Double Glass Fisheye etc',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Rare Honeywell (Asahi) Auto Strobonar 280S (Flash unit)',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Minolta X700 Rig',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'CAMERA COLLECTORS!!!!',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Attachment for Panasonic 3D lens and HD camcorder',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Vintage Halsman Marilyn prints',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'map',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Adapter Case 22.5L w foam pad',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Quantum QF63B Telephoto Reflector',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Mamiya 43mm f4.5L w Lenshade for M7',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Lowepro Pro Roller 2 Rolling Case',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Kodak Stack Loader Tray',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': ' LOWEL SNOOT for DP',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Contax N Digital and 24-85mm ',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Olympus M.Zuiko 17mm f1.8 (Black) f/ Olympus + Panasonic Micro 4/3 Cam',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': '35MM &amp; VIDEO CAMERAS',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': '35 MM CAMERA SET FOR SALE',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Olympus Pen EP-5 M4/3 Silver/Black Camera with VF-4 Viewfinder -LN',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': '_______FREE CABLE TV and MOVIES! - - - - - ',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Canon G10 Mint Condition',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'IDX Wevi Cam~Wave WIFI Video Transmission / Receiver system',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Asahi Pentax Spotmatic SP 35mm film Camera',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': '10 feet Underwater Waterproof Olympus, new condition',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'SIGMA EX 17-35 f2.8  FOR CANON',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Rode Shotgun Mic $200 OBO',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': ' Eyemo by  Bell &amp; Howell/ 35mm motion picture camera',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Voigtlander Prominent Camera - for Parts',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'map',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Taylor &amp; Hobson 1 inch f:1.9 C mount, bolex/m 4/3 lens',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'map',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'ISCO-GOTTINGEN ISCONAR 100/4.5 M42 Lens',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': '*RARE* Minox AF Mini - 35mm Point &amp; Shoot Camera (BEAUTIFUL!) ',
#   'section': 'for-sale'},
#  {'category': 'photography',
#   'city': 'newyork',
#   'heading': 'Canon 40D Kit + Box, Accessories, Pelican Case + Extras',
#   'section': 'for-sale'},
#  ...]

# %%
data[1:2]
# Out:
# [{'category': 'cell-phones',
#   'city': 'newyork',
#   'heading': 'New batteries C-S2 for Blackberry 7100/7130/8700/Curve/Pearl',
#   'section': 'for-sale'}]

# %%
my_data = data[1:]

# %%
category = []
city = []
heading = []
section = []

for i in my_data:
  
  category.append(i["category"])
  city.append(i["city"])
  heading.append(i["heading"])
  section.append(i["section"])

# %%
import pandas as pd
data_new = pd.DataFrame(
    {'city': city,
     'section': section,
     'heading': heading,
     'category':category
    })

# %%
data_new.head()
# Out:
#       city  ...     category
# 0  newyork  ...  cell-phones
# 1  newyork  ...  cell-phones
# 2  newyork  ...  cell-phones
# 3  newyork  ...  cell-phones
# 4  newyork  ...  cell-phones
#
# [5 rows x 4 columns]

# %%
data_new["category"].value_counts()
# Out:
# shared                2273
# therapeutic           2203
# cell-phones           1741
# temporary             1518
# appliances            1443
# household-services    1381
# photography           1379
# wanted-housing        1378
# childcare             1255
# video-games           1249
# automotive            1136
# real-estate           1048
# general               1020
# artists                439
# housing                397
# activities             357
# Name: category, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
chart = sns.countplot(
    data_new["category"])
chart.set_xticklabels(chart.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'cell-phones'),
#  Text(0, 0, 'appliances'),
#  Text(0, 0, 'photography'),
#  Text(0, 0, 'video-games'),
#  Text(0, 0, 'housing'),
#  Text(0, 0, 'shared'),
#  Text(0, 0, 'temporary'),
#  Text(0, 0, 'wanted-housing'),
#  Text(0, 0, 'activities'),
#  Text(0, 0, 'artists'),
#  Text(0, 0, 'childcare'),
#  Text(0, 0, 'general'),
#  Text(0, 0, 'automotive'),
#  Text(0, 0, 'household-services'),
#  Text(0, 0, 'real-estate'),
#  Text(0, 0, 'therapeutic')]

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20217 entries, 0 to 20216
# Data columns (total 4 columns):
# city        20217 non-null object
# section     20217 non-null object
# heading     20217 non-null object
# category    20217 non-null object
# dtypes: object(4)
# memory usage: 631.9+ KB

# %%
from sklearn.preprocessing import LabelBinarizer
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
targets = data_new["category"].values

# %%
encoder = LabelBinarizer()
encoder.fit(targets)
y_train = encoder.transform(targets)

# %%
from keras.models import Model
from keras.layers import Dense, Embedding, Input
from keras.layers import LSTM, Bidirectional, GlobalMaxPool1D, Dropout
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.optimizers import Adam

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# Out:
# --2019-07-02 15:44:56--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2019-07-02 15:44:56--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2019-07-02 15:44:56--  http://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  35.7MB/s    in 24s
#
# 2019-07-02 15:45:20 (34.6 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]

# %%
import zipfile
zip_ref = zipfile.ZipFile("glove.6B.zip", 'r')
zip_ref.extractall("glove")
zip_ref.close()

# %%
import numpy as np
# some configuration
MAX_SEQUENCE_LENGTH = 50
MAX_VOCAB_SIZE = 20000
EMBEDDING_DIM = 300
VALIDATION_SPLIT = 0.2
BATCH_SIZE = 128
EPOCHS = 5



# load in pre-trained word vectors
print('Loading word vectors...')
word2vec = {}
with open("glove/glove.6B.300d.txt") as f:
  # is just a space-separated text file in the format:
  # word vec[0] vec[1] vec[2] ...
  for line in f:
    values = line.split()
    word = values[0]
    vec = np.asarray(values[1:], dtype='float32')
    word2vec[word] = vec
print('Found %s word vectors.' % len(word2vec))
# Out:
# Loading word vectors...
# Found 400000 word vectors.

# %%
# convert the sentences (strings) into integers
tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE)
tokenizer.fit_on_texts(data_new["heading"])
sequences = tokenizer.texts_to_sequences(data_new["heading"])

# %%
# get word -> integer mapping
word2idx = tokenizer.word_index
print('Found %s unique tokens.' % len(word2idx))


# pad sequences so that we get a N x T matrix
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', data.shape)
# Out:
# Found 12743 unique tokens.
# Shape of data tensor: (20217, 50)

# %%
# prepare embedding matrix
print('Filling pre-trained embeddings...')
num_words = min(MAX_VOCAB_SIZE, len(word2idx) + 1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word2idx.items():
  if i < MAX_VOCAB_SIZE:
    embedding_vector = word2vec.get(word)
    if embedding_vector is not None:
      # words not found in embedding index will be all zeros.
        embedding_matrix[i] = embedding_vector
# Out:
# Filling pre-trained embeddings...

# %%
# load pre-trained word embeddings into an Embedding layer
# note that we set trainable = False so as to keep the embeddings fixed
embedding_layer = Embedding(
  num_words,
  EMBEDDING_DIM,
  weights=[embedding_matrix],
  input_length=MAX_SEQUENCE_LENGTH,
  trainable=False
)



print('Building model...')

# create an LSTM network with a single LSTM
input_ = Input(shape=(MAX_SEQUENCE_LENGTH,))
x = embedding_layer(input_)
# x = LSTM(15, return_sequences=True)(x)
x = Bidirectional(LSTM(15, return_sequences=True))(x)
x = GlobalMaxPool1D()(x)
output = Dense(16, activation="softmax")(x)

model = Model(input_, output)
model.compile(
  loss='binary_crossentropy',
  optimizer=Adam(lr=0.01),
  metrics=['accuracy']
)
# Out:
# Building model...

# %%
print('Training model...')
r = model.fit(
  data,
  y_train,
  batch_size=BATCH_SIZE,
  epochs=EPOCHS,
  validation_split=VALIDATION_SPLIT
)
# Out:
# Training model...
# Train on 16173 samples, validate on 4044 samples
# Epoch 1/5
# 16173/16173 [==============================] - 30s 2ms/step - loss: 0.1218 - acc: 0.9606 - val_loss: 0.0901 - val_acc: 0.9705
# Epoch 2/5
# 16173/16173 [==============================] - 28s 2ms/step - loss: 0.0860 - acc: 0.9716 - val_loss: 0.0959 - val_acc: 0.9678
# Epoch 3/5
# 16173/16173 [==============================] - 28s 2ms/step - loss: 0.0772 - acc: 0.9748 - val_loss: 0.1002 - val_acc: 0.9679
# Epoch 4/5
# 16173/16173 [==============================] - 28s 2ms/step - loss: 0.0705 - acc: 0.9771 - val_loss: 0.0993 - val_acc: 0.9681
# Epoch 5/5
# 16173/16173 [==============================] - 28s 2ms/step - loss: 0.0657 - acc: 0.9788 - val_loss: 0.0987 - val_acc: 0.9679

# %%
# !wget https://s3.amazonaws.com/hr-testcases/859/sample-test.in.json
# Out:
# --2019-07-02 16:01:26--  https://s3.amazonaws.com/hr-testcases/859/sample-test.in.json
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.129.45
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.129.45|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1385338 (1.3M) [application/octet-stream]
# Saving to: ‘sample-test.in.json’
#
# sample-test.in.json 100%[===================>]   1.32M  --.-KB/s    in 0.08s
#
# 2019-07-02 16:01:26 (16.1 MB/s) - ‘sample-test.in.json’ saved [1385338/1385338]

# %%
data_input = []
with open('sample-test.in.json') as f:
    for line in f:
        data_input.append(json.loads(line))

# %%
test_data = data_input[1:]

# %%
city = []
heading = []
section = []

for i in test_data:
  
  city.append(i["city"])
  heading.append(i["heading"])
  section.append(i["section"])

# %%
test = pd.DataFrame(
    {'city': city,
     'section': section,
     'heading': heading,
     })

# %%
test.head()
# Out:
#         city   section                                            heading
# 0    chicago  for-sale                 Madden NFL 25 XBOX 360. Brand New!
# 1   paris.en   housing                          looking for room to rent.
# 2    newyork  for-sale                                        two DS game
# 3    seattle   housing                                                map
# 4  singapore  services  Good Looking Asian Sensation N aughty Girl ---...

# %%
test.shape
# Out:
# (15370, 3)

# %%
test_sequences = tokenizer.texts_to_sequences(test["heading"])

# %%
test_pad = pad_sequences(test_sequences, maxlen=MAX_SEQUENCE_LENGTH, padding='post')

# %%
text_labels = encoder.classes_

# %%
text_labels
# Out:
# array(['activities', 'appliances', 'artists', 'automotive', 'cell-phones',
#        'childcare', 'general', 'household-services', 'housing',
#        'photography', 'real-estate', 'shared', 'temporary', 'therapeutic',
#        'video-games', 'wanted-housing'], dtype='<U18')

# %%
category_predicted = []
for i in range(test.shape[0]):
    prediction = model.predict(np.array([test_pad[i]]))
    predicted_label = text_labels[np.argmax(prediction[0])]
    category_predicted.append(predicted_label)

# %%
test["category"] = category_predicted

# %%
test
# Out:
#             city  ...            category
# 0        chicago  ...         video-games
# 1       paris.en  ...      wanted-housing
# 2        newyork  ...         video-games
# 3        seattle  ...          appliances
# 4      singapore  ...         therapeutic
# 5        newyork  ...          appliances
# 6      singapore  ...          appliances
# 7       dubai.en  ...         therapeutic
# 8         london  ...         therapeutic
# 9        chicago  ...             general
# 10        london  ...          appliances
# 11        london  ...         therapeutic
# 12       seattle  ...      wanted-housing
# 13       seattle  ...              shared
# 14        london  ...              shared
# 15       seattle  ...          appliances
# 16       chicago  ...          automotive
# 17     singapore  ...         cell-phones
# 18       newyork  ...           childcare
# 19       seattle  ...  household-services
# 20       newyork  ...           childcare
# 21       newyork  ...          appliances
# 22       newyork  ...             housing
# 23       seattle  ...             housing
# 24     hyderabad  ...         therapeutic
# 25       newyork  ...           temporary
# 26      dubai.en  ...          appliances
# 27       newyork  ...      wanted-housing
# 28     singapore  ...          appliances
# 29       newyork  ...      wanted-housing
# ...          ...  ...                 ...
# 15340    seattle  ...          appliances
# 15341    chicago  ...  household-services
# 15342    newyork  ...          appliances
# 15343    seattle  ...          appliances
# 15344    chicago  ...           childcare
# 15345  singapore  ...          appliances
# 15346    chicago  ...         photography
# 15347    chicago  ...          appliances
# 15348  singapore  ...              shared
# 15349     london  ...         therapeutic
# 15350    chicago  ...          appliances
# 15351    seattle  ...             general
# 15352   paris.en  ...              shared
# 15353     london  ...              shared
# 15354    newyork  ...          appliances
# 15355    seattle  ...             general
# 15356  singapore  ...         video-games
# 15357   paris.en  ...          appliances
# 15358    seattle  ...             general
# 15359     london  ...         therapeutic
# 15360     mumbai  ...         real-estate
# 15361    chicago  ...             artists
# 15362     london  ...         cell-phones
# 15363    seattle  ...             general
# 15364    chicago  ...          appliances
# 15365    newyork  ...          appliances
# 15366    seattle  ...          appliances
# 15367    seattle  ...             housing
# 15368    newyork  ...          appliances
# 15369    seattle  ...         video-games
#
# [15370 rows x 4 columns]

# %%
test.to_json("my_results.json")

# %%
test.to_csv("my_results_csv.csv")
